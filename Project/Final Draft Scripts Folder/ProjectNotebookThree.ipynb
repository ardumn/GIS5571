# %% [markdown]
# # Data Flow Diagram Three: Statistical Analysis of Stream Network and Comparison to Linear Directional Mean of Lineaments (Inference based on Properties)

# %% [markdown]
# ### Test One: Ordinary Least Squares of Stream Network for Investigating Geometry Dependency

# %%
arcpy.stats.OrdinaryLeastSquares("streams", "ARCID", r"C:\Users\danie861\Desktop\FinalProject\FinalProject\Default.gdb\streams_OrdinaryLeastSquares", "ARCID", "ARCID;GRID_CODE;FROM_NODE;TO_NODE;Shape_Length;NEAR_FID;NEAR_DIST;NEAR_X;NEAR_Y;NEAR_ANGLE", None, None, None)

# %% [markdown]
# ### Test Two: General Linear Regression (Continuous) of Stream Network for Investigating Geometry Features and Resilience

# %%
arcpy.gapro.GeneralizedLinearRegression("streams", "ARCID", "CONTINUOUS", "FROM_NODE;GRID_CODE;NEAR_ANGLE;NEAR_DIST;NEAR_FID;NEAR_X;NEAR_Y;Shape_Length;TO_NODE", r"C:\Users\danie861\Desktop\FinalProject\FinalProject\Default.gdb\StreamsGLR", None, None, None, None, None)

# %% [markdown]
# ### Test Three/Assessment: Assess Bias and Infer from Lineaments based on Stream Tests Produced and Charts (and Literature)

# %%
#See Final Project Report
